# %%
import pandas as pd

# Esto le dice a Pandas que muestre el contenido completo de las columnas,
# sin truncar el texto.
pd.options.display.max_colwidth = None

# Opcional: Esto asegura que todas las columnas sean visibles,
# no solo las que caben en la pantalla.
pd.options.display.max_columns = None

# %%
# -------------------------------------------------------
#                 IMPORTAR LIBRERIAS 
# ------------------------------------------------------

# importar librerias de manipulacion de Datos
import pandas as pd 
import numpy as np
import sys

file = '/mnt/c/DataScience/Projects_Python/Clinica_Prime/data/clientes_work.xlsx'
excel_file= pd.ExcelFile(file)
meses = excel_file.sheet_names


df_final = pd.DataFrame()

# Agiizar
# Nombre legibles no Deseados Se agregan a una lista llamada `eliminar_columna`
eliminar_columna = [ 'costo', #Redundante con el Total, no hace Referencia a Costo del Material
                     'fotos ',
                     'hora',
                     'hora.1',
                     'motivo de consulta',
                     'metodo de pago',
                     'metodo de pago.1',
                     'anuncio',
                     'deuda']

columnas_reemplazar =  ['tratamiento/procedimiento',
                       'procedimiento',
                       'notas.1']


map_columnas = {'tratamiento/procedimiento': 'tratamiento',
                       'procedimiento':'tratamiento',
                       'notas.1':'notas'}

nombres_base = ['edad',
                'nombre',
                'teléfono',
                'sexo',
                'dni',
                'nacimiento',
                'distrito',
                'total',
                'notas',
                'pp',
                'tratamiento',  
                'fecha']    

for mes in meses:
    df = excel_file.parse(mes)
    
    renombradas_encontradas = []
    descartados_encontrados = []
    desconocidas_encontradas = []
   
    
    try: 
        df.columns = [str(col).lower() for col in df.columns]
        for col in df.columns:
            if col not in nombres_base:
                # Eliminar Columnas no Deseadas
                if col in eliminar_columna:
                    print(f"\n Se Encontro columna a eliminar {col}")
                    df.drop(col, axis=1, inplace=True)
                    descartados_encontrados.append(col)
                    
                # Renombrar columnas Conocidas segun el Mapeo
                df.rename(columns=map_columnas, inplace=True)
                for col_map in map_columnas.keys():
                    if col_map in df.columns:
                        print(f"Renombrando Columna Conocida {col_map} -> {map_columnas[col_map]}")
                        renombradas_encontradas.append(col_map)
                
                # Identificar columnas desconocidas por el Tipo de Datos
                if col not in eliminar_columna and col not in columnas_reemplazar:
                    dtype = df[col].dtype
                    print(f"\n🔍 Analizando columna desconocida: {col} (tipo: {dtype})")
                    if dtype == 'datetime64[ns]':
                        df.rename(columns={col: 'fecha'}, inplace=True)
                    elif dtype == 'object':
                        df.rename(columns={col: 'tratamient'}, inplace=True)
        print(df.columns)
        
        df_final = pd.concat([df_final, df], ignore_index = True)

    except Exception as e:
        print(f"❌ MISIÓN ABORTADA en FASE 1. Error: {e}")
# Out:
# 🔍 Analizando columna desconocida: .0 (tipo: datetime64[ns])
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento',
#        'distrito', 'tratamiento', 'notas', 'total', 'pp'],
#       dtype='object')
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento',
#        'distrito', 'tratamiento', 'notas', 'total', 'pp'],
#       dtype='object')
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento',
#        'distrito', 'tratamiento', 'notas', 'total', 'pp'],
#       dtype='object')
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento',
#        'distrito', 'tratamiento', 'notas', 'total', 'pp'],
#       dtype='object')
#
#  Se Encontro columna a eliminar motivo de consulta
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento',
#        'distrito', 'tratamiento', 'notas', 'total', 'pp'],
#       dtype='object')
#
# 🔍 Analizando columna desconocida: jo (tipo: datetime64[ns])
#
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        1101 non-null   object
#  1   nombre       1094 non-null   object
#  2   edad         1024 non-null   object
#  3   teléfono     999 non-null    object
#  4   dni          917 non-null    object
#  5   sexo         1080 non-null   object
#  6   nacimiento   774 non-null    object
#  7   distrito     717 non-null    object
#  8   tratamiento  1000 non-null   object
#  9   notas        996 non-null    object
#  10  total        1070 non-null   object
#  11  pp           15 non-null     object
#  12  tratamient   87 non-null     object
# dtypes: object(13)
# memory usage: 112.6+ KB

# %%
# ======================================================================
# 🏛️ CIRUGÍA RECONSTRUCTIVA, PASO 1: FUSIÓN DE GEMELOS
# ======================================================================
# PRERREQUISITO: El DataFrame `df_final` existe.

print("--- Iniciando Fusión de Columnas Duplicadas ---")
print(f"Columnas antes de la fusión: {df_final.columns.tolist()}")

# La Anatomía: `.fillna()`
# El Propósito del Artesano: Le decimos a Pandas: "En la columna 'tratamiento',
# si encuentras una celda vacía (NaN), intenta rellenarla con el valor
# de la misma fila pero de la columna 'tratamient'".
# Esto es un trasplante de datos.
df_final['tratamiento'] = df_final['tratamiento'].fillna(df_final['tratamient'])

# La Anatomía: `.drop()`
# El Propósito del Artesano: Ahora que hemos salvado los datos de la columna
# redundante, la destruimos.
df_final.drop(columns=['tratamient'], inplace=True)

print("\n✅ Fusión completada.")
print(f"Columnas después de la fusión: {df_final.columns.tolist()}")

print("\n--- Verificación de la Estructura Post-Fusión ---")
print(df_final.info())
# Out:
# --- Iniciando Fusión de Columnas Duplicadas ---
# Columnas antes de la fusión: ['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento', 'distrito', 'tratamiento', 'notas', 'total', 'pp', 'tratamient']
#
# ✅ Fusión completada.
# Columnas después de la fusión: ['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento', 'distrito', 'tratamiento', 'notas', 'total', 'pp']
#
# --- Verificación de la Estructura Post-Fusión ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        1101 non-null   object
#  1   nombre       1094 non-null   object
#  2   edad         1024 non-null   object
#  3   teléfono     999 non-null    object
#  4   dni          917 non-null    object
#  5   sexo         1080 non-null   object
#  6   nacimiento   774 non-null    object
#  7   distrito     717 non-null    object
# ...

# %%
# Permitir que Python encunetre e importe funciones personlizadas
# `src/limpieza_utils.py`

import sys # Importa el Sistema interno  de Python
import os #Importa el sistema operativo -> Permite hablar con carpeta rutas y archivos

# Paso 1: Encontrar ruta del proyecto para poder establecer las conexiones ya sea con los datos y otra información a tener en cuenta
ruta_proyecto = os.path.dirname(os.getcwd())
# `os.getcwd()` -> Get CurrentWorking Directory -> Cual es la carpeta actual de Trabjo actual?
# `os.path.dirname(.....)` -> Dame el nombre de la Carpeta PADRE de la ruta que te doy


# Paso 2:Agregar la ruta del proyecto al mapa de python
sys.path.append(ruta_proyecto)
    #`sys.path` -> Lista de Carpetas donde Python busca modulos para importar
    
print(f"(--------- Ruta del proyecto {ruta_proyecto} agregado al mapa de Python--------------)")
# Out:
# (--------- Ruta del proyecto /mnt/c/DataScience/Projects_Python/Clinica_Prime agregado al mapa de Python--------------)

# %%
# ======================================================================
# 🏛️ LA OBRA - Aplicando la Purificación con Auditoría
# ======================================================================
# PRERREQUISITO: df_final existe. Taller .py actualizado. Kernel reiniciado.

# --- Importando nuestra nueva herramienta blindada ---
from src.limpieza_utils import estandarizar_texto

print("\n--- Iniciando la Fase de Purificación Profunda de Texto con Auditoría ---")

columnas_de_texto_clave = ['tratamiento', 'notas', 'nombre', 'distrito']

# --- El Proceso de Purificación Auditado ---
for columna in columnas_de_texto_clave:
    # Simplemente llamamos a la nueva función
    df_final = df_final.pipe(estandarizar_texto, nombre_columna=columna)

# --- INFORME FINAL DE ESTADO ---
print("\n\n--- 📋 INFORME FINAL DE NULOS POST-PURIFICACIÓN ---")
print(df_final[columnas_de_texto_clave].info())
# Out:
# --- Iniciando la Fase de Purificación Profunda de Texto con Auditoría ---
#
# --- 💧 Aplicando Purificación Profunda (Auditada) en 'tratamiento' ---
#      -> 📊 Estado Inicial: 1087 valores no nulos.
#      -> 📊 Estado Final:   1087 valores no nulos.
#  -> Peridad de Informacion minima
#
# --- 💧 Aplicando Purificación Profunda (Auditada) en 'notas' ---
#      -> 📊 Estado Inicial: 996 valores no nulos.
#      -> 📊 Estado Final:   996 valores no nulos.
#  -> Peridad de Informacion minima
#
# --- 💧 Aplicando Purificación Profunda (Auditada) en 'nombre' ---
#      -> 📊 Estado Inicial: 1094 valores no nulos.
#      -> 📊 Estado Final:   1093 valores no nulos.
#  -> Peridad de Informacion minima
#
# --- 💧 Aplicando Purificación Profunda (Auditada) en 'distrito' ---
#      -> 📊 Estado Inicial: 717 valores no nulos.
#      -> 📊 Estado Final:   716 valores no nulos.
#  -> Peridad de Informacion minima
#
#
# --- 📋 INFORME FINAL DE NULOS POST-PURIFICACIÓN ---
# ...

# %%
from src.limpieza_utils import convertir_a_fechas, limpiar_y_convertir_a_numerico

print("\n--- Iniciando la Cirugía de Tipos de Datos ---")
print("\n--- Estado PRE-Operatorio del Paciente ---")
print(df_final.info())
# Out:
# --- Iniciando la Cirugía de Tipos de Datos ---
#
# --- Estado PRE-Operatorio del Paciente ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        1101 non-null   object
#  1   nombre       1093 non-null   object
#  2   edad         1024 non-null   object
#  3   teléfono     999 non-null    object
#  4   dni          917 non-null    object
#  5   sexo         1080 non-null   object
#  6   nacimiento   774 non-null    object
#  7   distrito     716 non-null    object
#  8   tratamiento  1087 non-null   object
#  9   notas        996 non-null    object
#  10  total        1070 non-null   object
#  11  pp           15 non-null     object
# dtypes: object(12)
# memory usage: 103.9+ KB
# None

# %%
# --- Aplicando las Herramientas Quirúrgicas ---

# 1. Operación de Fechas
df_final = df_final.pipe(convertir_a_fechas, nombre_columna='fecha')
df_final = df_final.pipe(convertir_a_fechas, nombre_columna='nacimiento') # También para nacimiento

# 2. Operación de Columnas Numéricas
columnas_a_limpiar_numeric = ['total', 'dni', 'teléfono', 'edad']
for col in columnas_a_limpiar_numeric:
    df_final = df_final.pipe(limpiar_y_convertir_a_numerico, nombre_columna=col)
    
    # 2.1 Post-Operatorio: Conversión a Entero si es posible
    # Después de limpiar, `dni`, `teléfono`, `edad` son `float64` por los `NaN`.
    # Los convertimos a `Int64` para un formato más limpio.
    if col in ['dni', 'teléfono', 'edad']:
        # `errors='ignore'` es por si la columna no existiera, aunque ya lo comprobamos.
        df_final[col] = df_final[col].astype('Int64', errors='ignore')
# Out:
#  ----- Columna a Analizar fecha -----
#
#
#  ----- Columna a Analizar nacimiento -----
#
#   -> Aplicando herramienta: 'limpiar_y_convertir_a_numerico' en 'total'...
#   -> Aplicando herramienta: 'limpiar_y_convertir_a_numerico' en 'dni'...
#   -> Aplicando herramienta: 'limpiar_y_convertir_a_numerico' en 'teléfono'...
#   -> Aplicando herramienta: 'limpiar_y_convertir_a_numerico' en 'edad'...

# %%
print("\n\n--- Estado POST-Operatorio del Paciente ---")
print(df_final.info())
# Out:
# --- Estado POST-Operatorio del Paciente ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        1099 non-null   datetime64[ns]
#  1   nombre       1093 non-null   object
#  2   edad         984 non-null    Int64
#  3   teléfono     955 non-null    Int64
#  4   dni          874 non-null    Int64
#  5   sexo         1080 non-null   object
#  6   nacimiento   712 non-null    datetime64[ns]
#  7   distrito     716 non-null    object
#  8   tratamiento  1087 non-null   object
#  9   notas        996 non-null    object
#  10  total        1069 non-null   float64
#  11  pp           15 non-null     object
# dtypes: Int64(3), datetime64[ns](2), float64(1), object(6)
# memory usage: 107.2+ KB
# None

# %%
print("\n\n--- Muestra de Datos Post-Cirugía ---")
display(df_final[['fecha', 'total', 'dni', 'edad']].sample(14))
# Out:
# --- Muestra de Datos Post-Cirugía ---
#          fecha   total       dni  edad
# 660 2025-01-07   900.0  29963228    50
# 293 2024-08-24   130.0      <NA>  <NA>
# 306 2024-08-26  4000.0  73051645    27
# 767 2025-02-05  4300.0  29640599    49
# 992 2025-04-22  2500.0  41663787    44
# 498 2024-11-23  1275.0  29635341    47
# 376 2024-09-21   175.0  46342530    34
# 910 2025-03-29  3300.0  48338868    31
# 12  2024-01-23     NaN      <NA>    31
# 592 2024-12-20  3200.0  29323187    58
# 769 2025-02-05  1200.0  40522947    45
# 740 2025-01-27  1425.0  43644004    38
# 232 2024-07-29  2600.0  70123443    34
# 661 2025-01-07   800.0  46022116    35

# %%
print("\n--- Iniciando la Reconstrucción de Identidades ---")
print(f"\n--- Nulos ANTES de la reconstrucción ---")
print(df_final.isnull().sum())
print(df_final.info())
# Out:
# --- Iniciando la Reconstrucción de Identidades ---
#
# --- Nulos ANTES de la reconstrucción ---
# fecha             8
# nombre           14
# edad            123
# teléfono        152
# dni             233
# sexo             27
# nacimiento      395
# distrito        391
# tratamiento      20
# notas           111
# total            38
# pp             1092
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        1099 non-null   datetime64[ns]
#  1   nombre       1093 non-null   object
#  2   edad         984 non-null    Int64
#  3   teléfono     955 non-null    Int64
#  4   dni          874 non-null    Int64
#  5   sexo         1080 non-null   object
#  6   nacimiento   712 non-null    datetime64[ns]
#  7   distrito     716 non-null    object
#  8   tratamiento  1087 non-null   object
# ...

# %%
duplicated_dni = df_final.duplicated(subset = ['dni'], keep = False)
duplicated_name = df_final.duplicated(subset = ['nombre'], keep = False)
duplicates_dni_name = df_final.duplicated(subset = ['dni', 'nombre'], keep = False)

print('Numero de DNI Repetidos ',len(df_final[duplicated_dni]))
print('Numero de Nonbre Duplciados', len(df_final[duplicated_name]))
print('Numero de DNI & Nombre Duplciados', len(df_final[duplicates_dni_name]))
# Out:
# Numero de DNI Repetidos  633
# Numero de Nonbre Duplciados 330
# Numero de DNI & Nombre Duplciados 272

# %%
# ======================================================================
# 🏛️ LA OBRA - Aplicando las Herramientas de Paciente Problemático
# ======================================================================
# PRERREQUISITO: df_final existe, taller .py actualizado, Kernel reiniciado.

from src.limpieza_utils import consolidar_marcador_problematico, limpiar_nombre_problematico

print("\n--- Iniciando el Protocolo de Paciente Problemático ---")

# --- Muestra ANTES ---
columnas_a_revisar = ['nombre', 'pp']
print("\n--- Evidencia ANTES de la operación ---")
# Filtramos para ver solo las filas que son problemáticas por una u otra razón
display(df_final[
    df_final['nombre'].astype(str).str.contains(r'\(PP\)', na=False) |
    df_final['pp'].notnull()
][columnas_a_revisar])
# Out:
# --- Iniciando el Protocolo de Paciente Problemático ---
#
# --- Evidencia ANTES de la operación ---
#                                      nombre                    pp
# 29                karina lazo gallegos (pp)                     X
# 122   m. del carmen delgado villanueva (pp)                     X
# 193                          ely paira (pp)                     X
# 206                      reyna lluclla (pp)                     X
# 213                      teresa vargas (pp)                     X
# 266                   milagros troncos (pp)                     X
# 282                      gladys quilla (pp)                     X
# 507                   marisol costa mircuda                    PP
# 624                    karen torres caceres                    PP
# 647                    carmen rivera mnedoz
# 648                    antonia huamani (pp)                     X
# 789                     sady salas palacios                     X
# ...

# %%
# --- LA LÍNEA DE ENSAMBLAJE (EN EL ORDEN CORRECTO) ---
df_final = (df_final
            # 1. Primero, leemos la información y creamos nuestra columna de verdad.
            .pipe(consolidar_marcador_problematico)
            # 2. Después, y solo después, borramos el tatuaje del nombre.
            .pipe(limpiar_nombre_problematico)
           )
# Out:
#  -> consolidating `problematic patient` markers ....
#
#  -> Columns 'paciente_problematico' creada y 'pp' eliminada
#
#   ->  Cleaning Problematic patient markers from 'nombre' ...

# %%
df_final.columns
# Out:
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'nacimiento',
#        'distrito', 'tratamiento', 'notas', 'total', 'paciente_problematico'],
#       dtype='object')

# %%
# --- Muestra DESPUÉS ---
columnas_a_revisar_despues = ['nombre', 'paciente_problematico']
print("\n--- Evidencia DESPUÉS de la operación ---")
display(df_final[df_final['paciente_problematico'] == True][columnas_a_revisar_despues])
# Out:
# --- Evidencia DESPUÉS de la operación ---
#                                 nombre  paciente_problematico
# 29                karina lazo gallegos                   True
# 122   m. del carmen delgado villanueva                   True
# 193                          ely paira                   True
# 206                      reyna lluclla                   True
# 213                      teresa vargas                   True
# 266                   milagros troncos                   True
# 282                      gladys quilla                   True
# 507              marisol costa mircuda                   True
# 624               karen torres caceres                   True
# 647               carmen rivera mnedoz                   True
# 648                    antonia huamani                   True
# 789                sady salas palacios                   True
# 821         priscilla quiroz benavente                   True
# ...

# %%
# ======================================================================
# 🏛️ CIRUGÍA RECONSTRUCTIVA, PASO PREVIO: PURIFICACIÓN
# ======================================================================
# PRERREQUISITO: El DataFrame `df_final` existe.

# --- Importando la NUEVA herramienta ---
from src.limpieza_utils import reconstruir_identidades # La necesitamos después



# --- AHORA, Y SOLO AHORA, PROCEDEMOS CON LA RECONSTRUCCIÓN ---
print("\n--- Iniciando la Reconstrucción de Identidades (Ahora sobre datos puros) ---")
print(f"\n--- Nulos ANTES de la reconstrucción ---")
print(df_final[['dni', 'nombre']].isna().sum())
# Out:
# --- Iniciando la Reconstrucción de Identidades (Ahora sobre datos puros) ---
#
# --- Nulos ANTES de la reconstrucción ---
# dni       233
# nombre      0
# dtype: int64

# %%
df_final = df_final.pipe(reconstruir_identidades)

print(f"\n\n--- Nulos DESPUÉS de la reconstrucción ---")
print(df_final[['dni', 'nombre']].isna().sum())
# Out:
#   -> Aplicando herramienta REFORJADA: 'reconstruir_identidades'...
#      -> Mapa de la verdad creado con 637 DNI únicos.
#      -> 📜 Se intentó rellenar nombres...
#      -> 🆔 Se intentó rellenar DNIs...
#
#
# --- Nulos DESPUÉS de la reconstrucción ---
# dni       199
# nombre     12
# dtype: int64

# %%
# --- Aplicando la Directiva Final de la Empresa ---
# Ahora que hemos salvado todo lo posible, purgamos los registros
# que siguen siendo irrecuperables (sin DNI).
filas_antes_purga = len(df_final)
df_final.dropna(subset=['dni'], inplace=True)
filas_purgadas = filas_antes_purga - len(df_final)
print(f"\n--- Purga final completada: {filas_purgadas} filas irrecuperables eliminadas. ---")


print("\n\n--- Verificación Final de la Estructura ---")
print(df_final.info(show_counts=True))
# Out:
# --- Purga final completada: 199 filas irrecuperables eliminadas. ---
#
#
# --- Verificación Final de la Estructura ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 2 to 1106
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha                  907 non-null    datetime64[ns]
#  1   nombre                 908 non-null    object
#  2   edad                   879 non-null    Int64
#  3   teléfono               861 non-null    Int64
#  4   dni                    908 non-null    object
#  5   sexo                   903 non-null    object
#  6   nacimiento             703 non-null    datetime64[ns]
#  7   distrito               707 non-null    object
#  8   tratamiento            900 non-null    object
#  9   notas                  816 non-null    object
#  10  total                  884 non-null    float64
#  11  paciente_problematico  908 non-null    bool
# ...

# %%
df_final['nombre'] = df_final['nombre'].str.title()
df_final['nombre'].sample(20)
# Out:
# 867            Kelly Gutierrez Vilca
# 838            Lisbeth Marca Humpiri
# 752             Yuvita Mamani Yuvica
# 471                       Yeny Paiva
# 340                 Jose Luis Quispe
# 769             Karen Torres Caceres
# 547                 Martha Victorino
# 829               Karen Quispe Araca
# 1004    Brusheska Talavera Gutierrez
# 1077            Maryori Yepes Garcia
# 847         Elizabeth Albino Mendoza
# 349                       Kelly Meza
# 318                    Paola Arevalo
# 327            Carmen Podesta Bruner
# 308               Alejandrina Mamani
# 615            David Ticse Tolentino
# 506                    Sara Chamarra
# 695          Flor Maria Quispe Tacca
# 659            Treyci Najarro Garcia
# 312                   Jose Gutierrez
# Name: nombre, dtype: object

# %%
print("--------- Imputacion Fecha ------------")
nulos_fecha_antes = df_final['fecha'].isna().sum()
print(f" -> Numero de Fechas Nulas {nulos_fecha_antes}")
# Out:
# --------- Imputacion Fecha ------------
#  -> Numero de Fechas Nulas 1

# %%
'''
Consideracion se Ha Registrado en base a hojas de excel donde Cda hoja Respresentaba un Mes
'''
#`ffill`: Forward Fill (Llenado Hacia Adelante) Rellena el Valor Nulo con el Ultimo Valor Valido
df_final['fecha'].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_23795/1627604426.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final['fecha'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23795/1627604426.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_final['fecha'].fillna(method='ffill', inplace=True)

# %%
# --- Informe Post-Operatorio ---
nulos_despues = df_final['fecha'].isna().sum()
print(f"\n  -> Fechas nulas DESPUÉS de la operación: {nulos_despues}")

if nulos_fecha_antes > nulos_despues:
    print(f"  -> ✨ ¡ÉXITO! Se ha rescatado {nulos_fecha_antes - nulos_despues} registro de fecha.")
else:
    print("  -> No se encontraron fechas nulas que necesitaran ser rellenadas.")

print("\n--- Verificación Final de la Estructura ---")
print(df_final.info(show_counts=True))
# Out:
#   -> Fechas nulas DESPUÉS de la operación: 0
#   -> ✨ ¡ÉXITO! Se ha rescatado 1 registro de fecha.
#
# --- Verificación Final de la Estructura ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 2 to 1106
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha                  908 non-null    datetime64[ns]
#  1   nombre                 908 non-null    object
#  2   edad                   879 non-null    Int64
#  3   teléfono               861 non-null    Int64
#  4   dni                    908 non-null    object
#  5   sexo                   903 non-null    object
#  6   nacimiento             703 non-null    datetime64[ns]
#  7   distrito               707 non-null    object
#  8   tratamiento            900 non-null    object
#  9   notas                  816 non-null    object
#  10  total                  884 non-null    float64
# ...

# %%
df_final[df_final.duplicated(subset=['dni', 'nombre'], keep = False)].sort_values('dni').head(10)
# Out:
#          fecha                    nombre  edad   teléfono       dni sexo  \
# 683 2025-01-14  Giovanna Molina Siguenas    48  958514940  10143251    F
# 710 2025-01-21  Giovanna Molina Siguenas    48  958514940  10143251    F
# 307 2024-08-26        Alejandrina Mamani    77  928161636   2267028    F
# 308 2024-08-26        Alejandrina Mamani    77  928161636   2267028    F
# 351 2024-09-05          Martha Perochena    69  958952634  29246890    F
# 350 2024-09-05          Martha Perochena    69  958952634  29246890    F
# 508 2024-11-25       Mappy Arce Figueroa    51  995496656  29313661    F
# 531 2024-12-02       Mappy Arce Figueroa  <NA>  995966656  29313661    F
# 543 2024-12-05          Jose Luis Quispe    57  944188409  29349856    M
# 340 2024-04-23          Jose Luis Quispe    56  944188409  29349856    M
#
#     nacimiento     distrito     tratamiento                 notas   total  \
# 683 1976-02-03        cayma           botox      64 und + tizo am  1660.0
# ...

# %%
from src.limpieza_utils import convertir_a_categoria

# 1. Definimos las columnas que son candidatas a ser categóricas.
columnas_categoricas = ['sexo', 'distrito']

print("--- Iniciando la Fase de Optimización Final ---")
print("\n--- Dtypes ANTES de la optimización ---")
# Mostramos solo los tipos de las columnas que nos interesan
print(df_final[columnas_categoricas].dtypes)
# Out:
# --- Iniciando la Fase de Optimización Final ---
#
# --- Dtypes ANTES de la optimización ---
# sexo        object
# distrito    object
# dtype: object

# %%
# 2. Aplicamos nuestra herramienta reforjada.
df_optimizado = df_final.pipe(convertir_a_categoria, lista_columnas=columnas_categoricas)


print("\n--- Dtypes DESPUÉS de la optimización ---")
print(df_optimizado[columnas_categoricas].dtypes)
# Out:
#   -> ⚙️  Aplicando herramienta de optimización: 'convertir_a_categoria'...
#      -> Columna 'sexo' convertida a 'category'.
#      -> Columna 'distrito' convertida a 'category'.
#
# --- Dtypes DESPUÉS de la optimización ---
# sexo        category
# distrito    category
# dtype: object

# %%
df_final[['tratamiento', 'notas']].sample(25)
# Out:
#                 tratamiento  \
# 429                producto
# 613                   botox
# 1073             art filler
# 130          a. hialuronico
# 360                 ellanse
# 982                   botox
# 1070                  botox
# 723                 ellanse
# 257                producto
# 441                producto
# 964            botox, croma
# 269                producto
# 780      juvederm, radiesse
# 286                   botox
# 724                   botox
# 833                juvederm
# 665   botox, nctf, producto
# 594                consulta
# 443                   botox
# 209          botox fullface
# 960                producto
# 303                producto
# 893                   croma
# 468                   botox
# 220          botox fullface
#
#                                                             notas
# 429                                                tizo 3+tizo am
# 613                                                         50und
# ...

# %%
len(df_final['tratamiento'].unique())
# Out:
# 113

# %%
df_final['texto_consulta'] = df_final['tratamiento'] + ' ' + df_final['notas']

# %%
# En `main.ipynb`
from src.limpieza_utils import extraer_marcas_ordenado, extraer_servicios_jerarquico

# --- FASE 1: PURIFICACIÓN Y FUSIÓN ---
# ... (código para crear 'texto_consulta') ...

# --- FASE 2: EXTRACCIÓN MODULAR DE ENTIDADES (ORDEN CRÍTICO) ---
print("\n--- 🧠 Iniciando la Extracción Modular de Entidades... ---")

df_enriquecido = (df_final
                  # 1. Primero, siempre, detectamos las MARCAS específicas.
                  .pipe(extraer_marcas_ordenado, col_fuente='texto_consulta')
                  # 2. LUEGO, usamos las marcas para inferir los SERVICIOS.
                  .pipe(extraer_servicios_jerarquico, col_fuente='texto_consulta')
                 )

# --- FASE 3: VERIFICACIÓN ---
print("\n\n--- 🔬 Muestra de la Extracción Jerárquica ---")
columnas_a_mostrar = ['texto_consulta', 'marcas_detectadas', 'servicios_realizados']
display(df_enriquecido[columnas_a_mostrar].head(15))
# Out:
# --- 🧠 Iniciando la Extracción Modular de Entidades... ---
#   -> 🏷️  Aplicando Detector de Marcas Ordenado en 'texto_consulta'...
#   -> 👑 Aplicando Extractor Jerárquico de Servicios en 'texto_consulta'...
#
#
# --- 🔬 Muestra de la Extracción Jerárquica ---
#                                                                texto_consulta  \
# 2                                                        botox full face 64 u
# 6                                             a. hialuronico a. h. 2 jeringas
# 7                                                    a. hialuronico 1 jeringa
# 20                                                    radiesse b. de colageno
# 22                                                   ellanse b. de colageno m
# 29                                                        botox 50u/full face
# 33                                                        botox 64u full face
# 34                  pb serum enzimas serum relax/tizostick/reduccion de grasa
# ...

# %%
df_final.sample(15)
# Out:
#          fecha                   nombre  edad   teléfono       dni sexo  \
# 123 2024-05-13   Alejandra Laura Quispe    21  913918132  76156264    F
# 255 2024-08-08            Charo Bellido    42  958795744  41254948    F
# 645 2025-01-02  Katiuska Yessica Torres    38  963322206  44602022    F
# 943 2025-04-16  Alejandra Ramos Pacheco    32  958222341  72561349    F
# 585 2024-12-19    Carmen Rivera Mendoza    47  983113499  29712464    F
# 59  2024-02-23           Brunella Lopez  <NA>       <NA>  46342530    F
# 654 2025-01-04     Miguel Munoz Hurtado    31  941230525  74696858    M
# 320 2024-08-31        Elizabeth Velarde    26  921776020  72779430    F
# 807 2025-02-18  Aurelia Huallpa De Vaca    60  933189215  29364273    F
# 145 2024-06-04        Yesenia Contreras    32    9693554  71498310    F
# 987 2025-04-22         Kelly Meza Rojas    42  933798744  42034517    F
# 598 2024-12-21  Brunella Lopez Vizcarra    34  953276776  46342530    F
# ...

# %%
# --- Importando las nuevas herramientas ---
from src.limpieza_utils import desglosar_fecha

print("\n--- Iniciando Fase Final de Limpieza y Enriquecimiento ---")

# --- Aplicando el Desglose de Fecha (Eficiente) ---
# Fíjate cómo podemos reutilizar la misma función para cualquier columna de fecha.
df_final = df_final.pipe(desglosar_fecha, nombre_columna='nacimiento', prefijo='nacimiento')
# df_final = df_final.pipe(desglosar_fecha, nombre_columna='fecha', prefijo='consulta') # Si quisiéramos desglosar la fecha de consulta también
# Out:
# --- Iniciando Fase Final de Limpieza y Enriquecimiento ---
#   -> 🗓️  Aplicando herramienta: 'desglosar_fecha' en 'nacimiento'...
#      -> Columna 'nacimiento' desglosada y eliminada.

# %%
# --- 5. FASE DE FORJA DE DIMENSIONES ---
print("\n--- 🏛️  Forjando las Tablas de Dimensión Finales ---")

# 5A: Catálogo de Servicios
# Flatten the lists in the 'servicios_realizados' column and find unique values
nombres_servicios_unicos = pd.Series([item for sublist in df_final['servicios_realizados'].dropna() for item in sublist]).unique()
df_servicios_catalogo = pd.DataFrame(nombres_servicios_unicos, columns=['servicios_realizados'])
print(f"\n✅ Catálogo de Servicios forjado con {len(df_servicios_catalogo)} servicios únicos.")
display(df_servicios_catalogo)
# Out:
# --- 🏛️  Forjando las Tablas de Dimensión Finales ---
#
# ✅ Catálogo de Servicios forjado con 7 servicios únicos.
#                servicios_realizados
# 0                 Toxina Botulinica
# 1         Relleno Acido Hialuronico
# 2        Bioestimulador de Colageno
# 3             Enzimas Recombinantes
# 4  Venta de Producto Dermocosmetico
# 5           Mesoterapia Skinbooster
# 6                   Consulta Medica

# %%
df_final.groupby('dni')['servicios_realizados'].count().sort_values(ascending =False)
# Out:
# dni
# 80202338     10
# 47133521      8
# 46342530      6
# 45205312      6
# 29551107      6
#              ..
# 931699616     1
# 29302487      1
# 29272637      1
# 2406202       1
# 29346514      1
# Name: servicios_realizados, Length: 637, dtype: int64

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 2 to 1106
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha                  908 non-null    datetime64[ns]
#  1   nombre                 908 non-null    object
#  2   edad                   879 non-null    Int64
#  3   teléfono               861 non-null    Int64
#  4   dni                    908 non-null    object
#  5   sexo                   903 non-null    category
#  6   distrito               707 non-null    category
#  7   tratamiento            900 non-null    object
#  8   notas                  816 non-null    object
#  9   total                  884 non-null    float64
#  10  paciente_problematico  908 non-null    bool
#  11  texto_consulta         808 non-null    object
#  12  marcas_detectadas      908 non-null    object
#  13  servicios_realizados   908 non-null    object
# ...

# %%
df_final[df_final['dni']== '80202338']
# Out:
#          fecha         nombre  edad   teléfono       dni sexo  distrito  \
# 304 2024-08-26  Norma Huamani    50  950380841  80202338    F  a. cayma
# 305 2024-08-26  Norma Huamani    50  950380841  80202338    F  a. cayma
# 416 2024-10-08  Norma Huamani    50  950380841  80202338    F     cayma
# 417 2024-10-08  Norma Huamani    50  950380841  80202338    F     cayma
# 485 2024-11-18  Norma Huamani  <NA>       <NA>  80202338  NaN       NaN
# 650 2025-01-03  Norma Huamani    50  950380841  80202338    F     cayma
# 750 2025-01-29  Norma Huamani    50  950380841  80202338    F     cayma
# 751 2025-01-29  Norma Huamani    50  950380841  80202338    F     cayma
# 956 2025-04-17  Norma Huamani    50  950380841  80202338    F     cayma
# 957 2025-04-17  Norma Huamani    50  950380841  80202338    F     cayma
#
#            tratamiento  \
# 304              croma
# 305           producto
# 416        botox+croma
# 417           producto
# 485               None
# 650         pago deuda
# ...

# %%
# ---------------------------
# 4) COMPLETAR año de nacimiento si falta
# ---------------------------
faltan_nac = df_final['nacimiento_year'].isna()
df_final.loc[faltan_nac, 'nacimiento_year'] = (df_final.loc[faltan_nac, 'fecha'].dt.year - df_final.loc[faltan_nac, 'edad'])

# ---------------------------
# 5) Resumen de nulos (auditoría rápida)
# ---------------------------
nulos = df_final.isna().sum()
print(nulos)
# Out:
# fecha                      0
# nombre                     0
# edad                      29
# teléfono                  47
# dni                        0
# sexo                       5
# distrito                 201
# tratamiento                8
# notas                     92
# total                     24
# paciente_problematico      0
# texto_consulta           100
# marcas_detectadas          0
# servicios_realizados       0
# nacimiento_year           26
# nacimiento_month         205
# nacimiento_day           205
# dtype: int64

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 2 to 1106
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha                  908 non-null    datetime64[ns]
#  1   nombre                 908 non-null    object
#  2   edad                   879 non-null    Int64
#  3   teléfono               861 non-null    Int64
#  4   dni                    908 non-null    object
#  5   sexo                   903 non-null    category
#  6   distrito               707 non-null    category
#  7   tratamiento            900 non-null    object
#  8   notas                  816 non-null    object
#  9   total                  884 non-null    float64
#  10  paciente_problematico  908 non-null    bool
#  11  texto_consulta         808 non-null    object
#  12  marcas_detectadas      908 non-null    object
#  13  servicios_realizados   908 non-null    object
# ...

# %%
# ======================================================================

# --- Importando TODO nuestro nuevo maletín de herramientas ---
from src.limpieza_utils import (
    extraer_unidades,
    extraer_monto_deuda    
)

print("\n--- Iniciando la Cirugía de Precisión sobre la columna 'notas' ---")

# --- La Línea de Ensamblaje con `.pipe()` ---
# La Parábola del Pintor, de nuevo:
# 1. "Toma el `df_final`."
# 2. "Pásalo por la estación 'extraer_unidades'."
# 3. "Toma el resultado y pásalo por la estación 'marcar_deuda'."
# 4. "Toma el resultado y pásalo por la estación 'extraer_monto_deuda'."
# 5. "Toma el resultado y pásalo por la estación 'extraer_jeringas'."
# El código es un reflejo directo, limpio y legible de nuestro proceso mental.

df_final_enriquecido = (df_final
                        .pipe(extraer_unidades,'notas')
                        .pipe(extraer_monto_deuda, col_fuente='notas')
                       )
# Out:
# --- Iniciando la Cirugía de Precisión sobre la columna 'notas' ---
#   -> Applying Multi-Consumption Extractor to 'notas'...
#      -> ✅ Columna 'consumos_detectados' creada con listas de tuplas (cantidad, unidad).
#   -> Aplicando extractor de 'monto_deuda' en 'notas'...

# %%
# ... (código anterior) ...

# --- Importando la NUEVA herramienta reforjada ---
from src.limpieza_utils import marcar_deuda_con_contexto_reforjado
# (y las otras)

# --- La Línea de Ensamblaje Actualizada ---
df_final_enriquecido = (df_final
                        .pipe(marcar_deuda_con_contexto_reforjado, col_fuente='notas')
                       )
# Out:
#   ->  Applying reinforced contextual debt sensor to 'notas'...
#      -> Columna 'deuda_generada' creada con lógica de contexto reforjada.

# %%
df_final.columns
# Out:
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'distrito',
#        'tratamiento', 'notas', 'total', 'paciente_problematico',
#        'texto_consulta', 'marcas_detectadas', 'servicios_realizados',
#        'nacimiento_year', 'nacimiento_month', 'nacimiento_day',
#        'consumos_detectados', 'deuda_monto', 'deuda_generada'],
#       dtype='object')

# %%
# Muestra solo las filas donde al menos una de nuestras nuevas herramientas encontró algo.
display(df_final[['texto_consulta', 'marcas_detectadas', 'servicios_realizados', 'consumos_detectados', 'deuda_monto']].sample(15))
# Out:
#                                                                                                texto_consulta  \
# 477                                                                            juvederm lips + menton + nariz
# 741  botox+juvederm 64 und + 4 jeringas natural face tml + menton y enzimas regalo dr + tizo tinted y tizo am
# 60                                                                                        botox 50u full face
# 185                                                   botox fullface 50u fullface/a. hialuronico 2j->juvederm
# 859                                                                                              botox 50 und
# 371                                                                                           nctf 3 sesiones
# 334                                   a. hialuronico 1jeringa/juvederm/pb serum/(s/2500 pago en dolares $675)
# ...

# %%
df_final.columns
# Out:
# Index(['fecha', 'nombre', 'edad', 'teléfono', 'dni', 'sexo', 'distrito',
#        'tratamiento', 'notas', 'total', 'paciente_problematico',
#        'texto_consulta', 'marcas_detectadas', 'servicios_realizados',
#        'nacimiento_year', 'nacimiento_month', 'nacimiento_day',
#        'consumos_detectados', 'deuda_monto', 'deuda_generada'],
#       dtype='object')

# %%
deudores = df_final['deuda_generada'] == True
df_final[deudores][['notas','deuda_generada', 'deuda_monto']]
# Out:
#                                                                   notas  \
# 165                                                          deuda 1000
# 186                                  2jeringas->juvederm jalupro(deuda)
# 210                                         100u fullface (deuda s/400)
# 234  64u fullface/juvederm 6j/bioplastia de labios y ojeras/tml (deuda)
# 269                               b3 ampoile hydra - 30ml (deuda 2,600)
# 337                                                    deuda -> s/2,600
# 925                                                               deuda
# 946                                                deuda 1500 (15 mayo)
# 956              deuda 1800 ( primera cuota pendiente para mayo de 450)
#
#      deuda_generada  deuda_monto
# 165            True       1000.0
# 186            True          NaN
# 210            True        400.0
# 234            True          NaN
# 269            True       2600.0
# 337            True       2600.0
# ...

# %%
df_final.drop(['edad'], axis = 1, inplace = True)

# %%
duplicates = df_final.duplicated(subset=['dni', 'nombre'], keep = False)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 2 to 1106
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha                  908 non-null    datetime64[ns]
#  1   nombre                 908 non-null    object
#  2   teléfono               861 non-null    Int64
#  3   dni                    908 non-null    object
#  4   sexo                   903 non-null    category
#  5   distrito               707 non-null    category
#  6   tratamiento            900 non-null    object
#  7   notas                  816 non-null    object
#  8   total                  884 non-null    float64
#  9   paciente_problematico  908 non-null    bool
#  10  texto_consulta         808 non-null    object
#  11  marcas_detectadas      908 non-null    object
#  12  servicios_realizados   908 non-null    object
#  13  nacimiento_year        882 non-null    Int64
# ...

# %%
df_final[df_final.duplicated(subset=['dni', 'nombre'], keep = False)].sort_values(by=['nombre'])
# Out:
#          fecha                    nombre   teléfono       dni sexo   distrito  \
# 308 2024-08-26        Alejandrina Mamani  928161636   2267028    F       puno
# 307 2024-08-26        Alejandrina Mamani  928161636   2267028    F       puno
# 409 2024-10-07  Alonso Bladimir Valencia  947113210  47450068    M  m. melgar
# 410 2024-10-07  Alonso Bladimir Valencia  947113210  47450068    M  m. melgar
# 691 2025-01-17   Ana Lucia Cacya Condori  977312131  48111653    F    sachaca
# ..         ...                       ...        ...       ...  ...        ...
# 284 2024-08-24          Yessenia Bolivar  959384478  29617447    F  yanahuara
# 438 2024-10-28          Yessenia Bolivar  959384478  29617447    F  yanahuara
# 285 2024-08-24          Yessenia Bolivar  959384478  29617447    F  yanahuara
# 524 2024-11-30       Zally Calcina Rojas  990822256  43567271    F        NaN
# 532 2024-12-02       Zally Calcina Rojas  990822256  43567271    F    cercado
#
# ...

# %%
df_final.columns
# Out:
# Index(['fecha', 'nombre', 'teléfono', 'dni', 'sexo', 'distrito', 'tratamiento',
#        'notas', 'total', 'paciente_problematico', 'texto_consulta',
#        'marcas_detectadas', 'servicios_realizados', 'nacimiento_year',
#        'nacimiento_month', 'nacimiento_day', 'consumos_detectados',
#        'deuda_monto', 'deuda_generada'],
#       dtype='object')

# %%
from src.limpieza_utils import consolidar_informacion_paciente
df_final = df_final.pipe(consolidar_informacion_paciente, columnas_a_consolidar=['teléfono', 'sexo', 'distrito','nacimiento_year',  'nacimiento_month', 'nacimiento_day' ])
# Out:
#   -> ✨ Aplicando COALESCE de Pandas para las columnas: ['teléfono', 'sexo', 'distrito', 'nacimiento_year', 'nacimiento_month', 'nacimiento_day']...
#      -> Consolidando 'teléfono'...
#      -> Consolidando 'sexo'...
#      -> Consolidando 'distrito'...
#      -> Consolidando 'nacimiento_year'...
#      -> Consolidando 'nacimiento_month'...
#      -> Consolidando 'nacimiento_day'...

# %%
df_duplicates = df_final[df_final.duplicated(subset=['dni', 'nombre'], keep = False)].sort_values(by=['nombre'])

df_duplicates.isna().sum()
# Out:
# fecha                      0
# nombre                     0
# teléfono                   0
# dni                        0
# sexo                       0
# distrito                  24
# tratamiento                5
# notas                     27
# total                     10
# paciente_problematico      0
# texto_consulta            32
# marcas_detectadas          0
# servicios_realizados       0
# nacimiento_year            0
# nacimiento_month          23
# nacimiento_day            23
# consumos_detectados       27
# deuda_monto              270
# deuda_generada             0
# dtype: int64

# %%
df_duplicates[df_duplicates[['nombre','teléfono', 'sexo', 'distrito','nacimiento_year',  'nacimiento_month', 'nacimiento_day' ]].isna().any(axis=1)][['nombre','teléfono', 'sexo', 'distrito','nacimiento_year',  'nacimiento_month', 'nacimiento_day' ]].sort_values(by=['nombre'])
# Out:
#                        nombre     teléfono sexo  distrito  nacimiento_year  \
# 691   Ana Lucia Cacya Condori    977312131    F   sachaca             1995
# 613   Ana Lucia Cacya Condori    977312131    F   sachaca             1994
# 595   Anthony Vergara Davalos    994335658    F       NaN             1995
# 325   Anthony Vergara Davalos    994335658    M       NaN             1995
# 236             Elena Cabrera    950853030    F       NaN             1989
# 184             Elena Cabrera    950853030    F       NaN             1989
# 420           Herlinda Huaman    959783833    F       NaN             1972
# 150           Herlinda Huaman    959783833    F       NaN             1972
# 453         Leslie Villanueva    958833784    F       NaN             1977
# 113         Leslie Villanueva    958833784    F       NaN             1977
# 721            Lorena Riveros    974321336    F       NaN             1984
# ...

# %%
df_final.sample(5)
# Out:
#          fecha                    nombre    teléfono       dni sexo  \
# 510 2024-11-26           Jessica Calcina  7012607340  72427705    F
# 244 2024-08-06          Lucero Rodriguez   925387770  45960278    F
# 410 2024-10-07  Alonso Bladimir Valencia   947113210  47450068    M
# 734 2025-01-27  Karely Rodriguez Encinas   936503173  60982851    F
# 33  2024-02-05              Aydee Mamani   950288286  29551107    F
#
#        distrito        tratamiento                               notas  \
# 510         NaN            ellanse             ellanse m (720 dolares)
# 244   s. alegre     botox+radiesse                          50u/(bbva)
# 410   m. melgar           producto                              tizo 3
# 734  paucarpata  botox, art filler  50 und + natural face tml + labios
# 33   paucarpata              botox                       64u full face
#
#       total  paciente_problematico  \
# 510  2700.0                  False
# 244  3000.0                  False
# ...

# %%
df_final['distrito'] = df_final['distrito'].str.upper()

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 908 entries, 2 to 1106
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha                  908 non-null    datetime64[ns]
#  1   nombre                 908 non-null    object
#  2   teléfono               896 non-null    Int64
#  3   dni                    908 non-null    object
#  4   sexo                   908 non-null    category
#  5   distrito               794 non-null    object
#  6   tratamiento            900 non-null    object
#  7   notas                  816 non-null    object
#  8   total                  884 non-null    float64
#  9   paciente_problematico  908 non-null    bool
#  10  texto_consulta         808 non-null    object
#  11  marcas_detectadas      908 non-null    object
#  12  servicios_realizados   908 non-null    object
#  13  nacimiento_year        908 non-null    Int64
# ...

# %%
# Check if the length of 'marcas_detectadas' and 'servicios_realizados' is greater than or equal to 2 for each row
mas_de_dos_marcas = df_final['marcas_detectadas'].apply(lambda x: len(x) >= 2 if isinstance(x, list) else False)
mas_de_dos_servicios = df_final['servicios_realizados'].apply(lambda x: len(x) >= 2 if isinstance(x, list) else False)

# Filter the DataFrame based on the conditions
df_final[(mas_de_dos_marcas) & (mas_de_dos_servicios)]
# Out:
#           fecha                            nombre   teléfono       dni sexo  \
# 34   2024-02-07             Monica Salinas Suarez  992370005  70262065    F
# 82   2024-03-09            Jenny Pacheco Palomino  984516579  41403583    F
# 91   2024-03-25                  Yesica Cateriano  986645375  29626660    F
# 106  2024-05-06                  Fiorela Tririnos  955791748  75571574    F
# 108  2024-05-07                  Carolina Herrera  956005599    584682    F
# ...         ...                               ...        ...       ...  ...
# 1088 2025-05-10  Dania Lourdes Zeballos Velasquez  950960015  42191976    F
# 1092 2025-05-12            Eva Ccotohuanca Quispe  986860984  41656771    F
# 1093 2025-05-12                  Yhandira Shirley  958167009  44835402    F
# 1095 2025-05-13   Martha Soledad Yupanqui Cahuana  976268394  29659571    F
# 1105 2025-05-16                Ruth Cutipa Huayta  914070161  29721802    F
#
#          distrito                 tratamiento  \
# ...

# %%
df_final.columns
# Out:
# Index(['fecha', 'nombre', 'teléfono', 'dni', 'sexo', 'distrito', 'tratamiento',
#        'notas', 'total', 'paciente_problematico', 'texto_consulta',
#        'marcas_detectadas', 'servicios_realizados', 'nacimiento_year',
#        'nacimiento_month', 'nacimiento_day', 'consumos_detectados',
#        'deuda_monto', 'deuda_generada'],
#       dtype='object')

# %%
a = df_final.duplicated(subset=['marcas_detectadas'], keep='first')
df_final[a]['marcas_detectadas']
# Out:
# 7                  []
# 29            [BOTOX]
# 33            [BOTOX]
# 59          [ELLANSE]
# 60            [BOTOX]
#             ...
# 1101       [JUVEDERM]
# 1102     [ART FILLER]
# 1103       [JUVEDERM]
# 1105    [BOTOX, TIZO]
# 1106          [BOTOX]
# Name: marcas_detectadas, Length: 808, dtype: object

# %%
display(df_final[['texto_consulta','servicios_realizados','marcas_detectadas','consumos_detectados' ,'total']].sample(20))
# Out:
#                                                                      texto_consulta  \
# 555                              botox + producto + ellanse 50u fullface/ m /tizo 3
# 701                                                                    botox 64 und
# 483                                                         juvederm lips + enzimas
# 695                 botox+juvederm, ellanse 64 und, 6 jeringas juvederm y ellanse m
# 450                                                                    botox 50 und
# 684                                      botox+juvederm 64 und + tml + ojera + lips
# 579                                                                    botox 64 und
# 826                                                                      croma rino
# 1008                                                        botox, harmonyca 64 und
# 901                                                                    botox 50 und
# ...

# %%
# ======================================================================
# 🏛️ LA OBRA - Orquestando con el Asignador de Genéricos
# ======================================================================
# PRERREQUISITO: Taller `limpieza_utils.py` actualizado, Kernel reiniciado.

# --- Importando la NUEVA herramienta ---
from src.limpieza_utils import  asignar_marcas_genericas

# --- La Línea de Ensamblaje Final ---
df_limpio_final = (df_final
                   #Después, nuestro nuevo supervisor de calidad corrige los vacíos.
                   .pipe(asignar_marcas_genericas)
                   
                   # ... (tus pipes posteriores) ...
                  )

# --- Verificación de la Operación ---
print("\n\n--- Verificación de la Asignación de Genéricos ---")
columnas_a_mostrar = [
    'texto_consulta',
    'servicios_realizados',
    'marcas_detectadas'
]

# Creamos un filtro para ver filas que originalmente no tenían marca pero sí servicio
filtro_sin_marca_original = df_final['marcas_detectadas'].apply(len) == 0

filtro_con_servicio = df_final['servicios_realizados'].apply(len) > 0

# Ahora mostramos esas mismas filas en el DF procesado para ver si se rellenaron
display(df_limpio_final.loc[filtro_sin_marca_original & filtro_con_servicio, columnas_a_mostrar])
# Out:
#   -> 🤖 Aplicando asignador de marcas genéricas contextuales...
#      -> Asignación completada.
#
#
# --- Verificación de la Asignación de Genéricos ---
#                       texto_consulta                servicios_realizados  \
# 254                       consulta -                   [Consulta Medica]
# 257                       producto -  [Venta de Producto Dermocosmetico]
# 413  producto micro peel sebia clear  [Venta de Producto Dermocosmetico]
# 541                consulta consulta                   [Consulta Medica]
# 556  consulta pago consulta con $100                   [Consulta Medica]
# 607   consulta cancelo el 20/12/2024                   [Consulta Medica]
# 799                consulta consulta                   [Consulta Medica]
#
#     marcas_detectadas
# 254                []
# 257                []
# 413                []
# 541                []
# 556                []
# 607                []
# 799                []

# %%
df_final.drop(columns = ['tratamiento', 'notas'], inplace = True)

# %%
len(df_final['dni'].unique())
# Out:
# 637

# %%
#================================================================================
# BRANCH - ETL - SQL
#=================================================================================

from sqlalchemy import create_engine, text 
import sys

from src.hidden import secret_credentials
secrets = secret_credentials()

user = secrets['user']
password = secrets['password']
host = secrets['host']
port = secrets['port']
database = secrets['database']


# =/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=
#  LA FUNCIÓN ORQUESTADORA - EN TU NOTEBOOK DE PYTHON
# =/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=/=
import traceback
from pathlib import Path
from sqlalchemy import text # ¡Importante importar `text`!

def run_sql_file(engine, sql_path, verify_query=None, verify_label=""):
    """
    Lee un archivo .sql y lo ejecuta contra la base de datos de la forma más robusta.
    """
    path = Path(sql_path)
    if not path.is_file():
        print(f"❌ Error: El archivo de plano '{path.name}' no fue encontrado en la ruta.")
        return

    print(f"\n  ----- Running SQL: {path} ------")
    
    try:
        # --- PASO 1: LEER EL CONTENIDO DEL ARCHIVO ---
        # Leemos el archivo .sql completo como una única cadena de texto.
        with open(path, 'r', encoding='utf-8') as f:
            sql_script = f.read()
        
        # --- PASO 2: EJECUCIÓN DIRECTA Y ROBUSTA ---
        # La Anatomía: `with engine.connect() as connection:`
        # El Propósito: Abrimos una conexión directa y la gestionamos de forma segura.
        # La Anatomía: `connection.execute(text(sql_script))`
        # El Propósito: `text()` le dice a SQLAlchemy "trata esta cadena de texto
        # como un bloque de SQL puro y ejecútalo tal cual, sin intentar ser demasiado listo".
        # Esto evita las capas internas que causaban el TypeError.
        # `connection.commit()` asegura que los cambios se guarden permanentemente.
        with engine.connect() as connection:
            connection.execute(text(sql_script))
            connection.commit() # Explícitamente guardamos la transacción.

        print(f"   Success: {path.name} executed")

        # --- PASO 3: VERIFICACIÓN (Sin cambios) ---
        if verify_query:
            with engine.connect() as connection:
                result = connection.execute(text(verify_query)).scalar()
                print(f"   Verification -> {verify_label}: {result} registros.")

    except Exception as e:
        print(f"   Failed Executing: {path}")
        print(f"   Script head: {sql_script[:200]}...")
        print("   Traceback:")
        traceback.print_exc()
        raise e
    
try: 
    engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}")
except Exception as e: 
    print(f"Fallo de Conexion: {e}")
    sys.exit() 
# Creacion de la Funcion para ejecutar los Archivos `sql`
'''
def run_sql_file(engine, sql_path: str, verify_query: str | None=None, verify_label:str = "verification"):

    path = Path(sql_path)
    print(f"\n  ----- Running SQL: {path} ------")
    if not path.exists():
        raise FileNotFoundError(f"SQL file not found: {path}")
    
    try: 
        sql = path.read_text(encoding="utf-8")
        # exec_driver _sql maneja sripts con multiples sentencias separadas por ';'
        with engine.begin() as conn:
            conn.exec_driver_sql(sql)
        print(f"Success: {path.name} executed")
        
        if verify_query: 
            with engine.connect() as conn:
                df_check = pd.read_sql_query(verify_query, conn)
                print(f"{verify_label}: \n{df_check.to_string(index=False)}")
    
    except Exception as e:
        print(f"Failed Executing: {path}")
        snippet = sql[:300].replace("\n", " ")
        print(f"   Script head: {snippet} ...")
        print("   Traceback:")
        traceback.print_exc()
        raise e  # re-lanza para que cualquier pipeline/CI lo detecte

            
                
                
'''
# Out:
# '\ndef run_sql_file(engine, sql_path: str, verify_query: str | None=None, verify_label:str = "verification"):\n\n    path = Path(sql_path)\n    print(f"\n  ----- Running SQL: {path} ------")\n    if not path.exists():\n        raise FileNotFoundError(f"SQL file not found: {path}")\n\n    try: \n        sql = path.read_text(encoding="utf-8")\n        # exec_driver _sql maneja sripts con multiples sentencias separadas por \';\'\n        with engine.begin() as conn:\n            conn.exec_driver_sql(sql)\n        print(f"Success: {path.name} executed")\n\n        if verify_query: \n            with engine.connect() as conn:\n                df_check = pd.read_sql_query(verify_query, conn)\n                print(f"{verify_label}: \n{df_check.to_string(index=False)}")\n\n    except Exception as e:\n        print(f"Failed Executing: {path}")\n        snippet = sql[:300].replace("\n", " ")\n        print(f"   Script head: {snippet} ...")\n        print("   Traceback:")\n        traceback.pr
# ...

# %%
# ======================================================================
# 🏛️ FASE FINAL: LA ORQUESTACIÓN DE LA CONSTRUCCIÓN DEL TEMPLO
# ======================================================================
# PRERREQUISITOS:
#   - El `engine` de SQLAlchemy existe.
#   - Tu función `run_sql_file` está en `src/limpieza_utils.py`.
#   - Los archivos .sql están en la carpeta `sql/`.

import pandas as pd
from sqlalchemy import text
from pathlib import Path
import sys
import os

# --- PASO 1: CONFIGURACIÓN DEL MAPA DE RUTAS (El GPS del Proyecto) ---
# La Anatomía: Este es el hechizo que le enseña a tu notebook a ver todo el proyecto.
# `Path.cwd()`: "Dame la ruta de la carpeta donde estoy corriendo AHORA MISMO"
#               (ej. '/.../Clinica_Prime/notebooks')
# `.parent`: "Dame la carpeta padre de esa ruta" (ej. '/.../Clinica_Prime')
# `ROOT_DIR` es ahora la raíz de tu proyecto. Es nuestro punto de referencia universal.
ROOT_DIR = Path(os.getcwd()).parent
sys.path.append(str(ROOT_DIR))

# Ahora podemos importar nuestra función de forma segura.

print(f"✅ Entorno configurado. Raíz del proyecto: {ROOT_DIR}")


# --- PASO 2: LA LISTA DE PLANOS (El Orden de Construcción) ---
# La Anatomía: Una lista de strings. El orden es CRÍTICO.
# Define la secuencia exacta en la que se construirá el Templo.
planos_de_construccion = [
    "01_create_schema.sql"]
print(f"  -> {len(planos_de_construccion)} planos listos para ser ejecutados.")


# --- PASO 3: LA EJECUCIÓN ORQUESTADA (El Maestro de Obras en Acción) ---
print("\n--- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---")

# La Anatomía: Iteramos sobre nuestra lista de planos.
for nombre_plano in planos_de_construccion:
    # La Lógica de Rutas del Maestro:
    # `ROOT_DIR / 'sql' / nombre_plano`: `pathlib` nos permite construir rutas
    # usando el operador `/` como si fueran carpetas. Es legible y robusto.
    # Esto crea la ruta ABSOLUTA y correcta al archivo .sql, sin importar
    # desde dónde ejecutes el notebook.
    ruta_plano_absoluta = ROOT_DIR / 'src' / 'sql' / nombre_plano
    
    # --- Verificaciones Opcionales para Cada Plano ---
    # Podemos añadir verificaciones específicas para cada paso.
    verify_query = None
    verify_label = None
    if nombre_plano == "01_create_schema.sql":
        verify_query = "SELECT column_name FROM information_schema.columns WHERE  table_name = 'pacientes';"
        verify_label = "Conteo de Pacientes Únicos"
    
    # Llamamos a nuestra poderosa función con la ruta absoluta.
    run_sql_file(
        engine,
        sql_path=str(ruta_plano_absoluta), # Convertimos a string para la función
        verify_query=verify_query,
        verify_label=verify_label
    )

print("\n\n--- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---")
# Out:
# ✅ Entorno configurado. Raíz del proyecto: /mnt/c/DataScience/Projects_Python/Clinica_Prime
#   -> 1 planos listos para ser ejecutados.
#
# --- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/01_create_schema.sql ------
#    Success: 01_create_schema.sql executed
#    Verification -> Conteo de Pacientes Únicos: id_paciente registros.
#
#
# --- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---

# %%
print('Creacion de la `Stagging Table`')

try: 
    df_final.to_sql('raw_data',
                con = engine , 
                if_exists='append',
                index=False
                )
    
except Exception as e: 
    print(f"Problema para poder Subir infomracion")
# Out:
# Creacion de la `Stagging Table`

# %%
planos_de_construccion = ["02a_insert_dimensions.sql",
                          "02b_insert_dimensions.sql"]
print(f"  -> {len(planos_de_construccion)} planos listos para ser ejecutados.")


# --- PASO 3: LA EJECUCIÓN ORQUESTADA (El Maestro de Obras en Acción) ---
print("\n--- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---")

# La Anatomía: Iteramos sobre nuestra lista de planos.
for nombre_plano in planos_de_construccion:
    # La Lógica de Rutas del Maestro:
    # `ROOT_DIR / 'sql' / nombre_plano`: `pathlib` nos permite construir rutas
    # usando el operador `/` como si fueran carpetas. Es legible y robusto.
    # Esto crea la ruta ABSOLUTA y correcta al archivo .sql, sin importar
    # desde dónde ejecutes el notebook.
    ruta_plano_absoluta = ROOT_DIR / 'src' / 'sql' / nombre_plano
    
    # --- Verificaciones Opcionales para Cada Plano ---
    # Podemos añadir verificaciones específicas para cada paso.
    verify_query = None
    verify_label = None
    if nombre_plano == "02_insert_dimensions.sql":
        verify_query = " SELECT COUNT(*) FROM servicios_catalogo;"
        verify_label = "Conteo de Catalogos y Servicios Unicos"
    if nombre_plano == "02b_insert_dimensions.sql":
        verify_query = "SELECT COUNT(*) FROM productos_catalogo;"
        verify_label = "Conteo de Catalogos y Servicios Unicos"
    
    
    
    
    # Llamamos a nuestra poderosa función con la ruta absoluta.
    run_sql_file(
        engine,
        sql_path=str(ruta_plano_absoluta), # Convertimos a string para la función
        verify_query=verify_query,
        verify_label=verify_label
    )

print("\n\n--- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---")
# Out:
#   -> 2 planos listos para ser ejecutados.
#
# --- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/02a_insert_dimensions.sql ------
#    Success: 02a_insert_dimensions.sql executed
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/02b_insert_dimensions.sql ------
#    Success: 02b_insert_dimensions.sql executed
#    Verification -> Conteo de Catalogos y Servicios Unicos: 20 registros.
#
#
# --- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---

# %%
planos_de_construccion = ["02c_insert_dimensions.sql",
                          "02d_insert_dimensions.sql"]
print(f"  -> {len(planos_de_construccion)} planos listos para ser ejecutados.")


# --- PASO 3: LA EJECUCIÓN ORQUESTADA (El Maestro de Obras en Acción) ---
print("\n--- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---")


# La Anatomía: Iteramos sobre nuestra lista de planos.
for nombre_plano in planos_de_construccion:
    # La Lógica de Rutas del Maestro:
    # `ROOT_DIR / 'sql' / nombre_plano`: `pathlib` nos permite construir rutas
    # usando el operador `/` como si fueran carpetas. Es legible y robusto.
    # Esto crea la ruta ABSOLUTA y correcta al archivo .sql, sin importar
    # desde dónde ejecutes el notebook.
    ruta_plano_absoluta = ROOT_DIR / 'src' / 'sql' / nombre_plano
    
    # --- Verificaciones Opcionales para Cada Plano ---
    # Podemos añadir verificaciones específicas para cada paso.
    verify_query = None
    verify_label = None
    if nombre_plano == "02c_insert_dimensions.sql":
        verify_query = " SELECT COUNT(*) FROM descuentos;"
        verify_label = "Conteo de Catalogos y Servicios Unicos"
    if nombre_plano == "02d_insert_dimensions.sql":
        verify_query = "SELECT COUNT(*) FROM distritos;"
        verify_label = "Conteo de Catalogos y Servicios Unicos"
    
    
    
    
    # Llamamos a nuestra poderosa función con la ruta absoluta.
    run_sql_file(
        engine,
        sql_path=str(ruta_plano_absoluta), # Convertimos a string para la función
        verify_query=verify_query,
        verify_label=verify_label
    )

print("\n\n--- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---")
# Out:
#   -> 2 planos listos para ser ejecutados.
#
# --- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/02c_insert_dimensions.sql ------
#    Success: 02c_insert_dimensions.sql executed
#    Verification -> Conteo de Catalogos y Servicios Unicos: 4 registros.
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/02d_insert_dimensions.sql ------
#    Success: 02d_insert_dimensions.sql executed
#    Verification -> Conteo de Catalogos y Servicios Unicos: 28 registros.
#
#
# --- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---

# %%
planos_de_construccion = [
    "03_insert_pacientes.sql"]
print(f"  -> {len(planos_de_construccion)} planos listos para ser ejecutados.")


# --- PASO 3: LA EJECUCIÓN ORQUESTADA (El Maestro de Obras en Acción) ---
print("\n--- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---")

# La Anatomía: Iteramos sobre nuestra lista de planos.
for nombre_plano in planos_de_construccion:
    # La Lógica de Rutas del Maestro:
    # `ROOT_DIR / 'sql' / nombre_plano`: `pathlib` nos permite construir rutas
    # usando el operador `/` como si fueran carpetas. Es legible y robusto.
    # Esto crea la ruta ABSOLUTA y correcta al archivo .sql, sin importar
    # desde dónde ejecutes el notebook.
    ruta_plano_absoluta = ROOT_DIR / 'src' / 'sql' / nombre_plano
    
    # --- Verificaciones Opcionales para Cada Plano ---
    # Podemos añadir verificaciones específicas para cada paso.
    verify_query = None
    verify_label = None
    if nombre_plano == "03_insert_pacientes.sql":
        verify_query = "SELECT COUNT(*) FROM pacientes;"
        verify_label = "Conteo de Pacientes Únicos"
    
    # Llamamos a nuestra poderosa función con la ruta absoluta.
    run_sql_file(
        engine,
        sql_path=str(ruta_plano_absoluta), # Convertimos a string para la función
        verify_query=verify_query,
        verify_label=verify_label
    )

print("\n\n--- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---")
# Out:
#   -> 1 planos listos para ser ejecutados.
#
# --- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/03_insert_pacientes.sql ------
#    Success: 03_insert_pacientes.sql executed
#    Verification -> Conteo de Pacientes Únicos: 637 registros.
#
#
# --- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---

# %%
planos_de_construccion = [
    "04_insert_consultas.sql",
    "05_insert_consultas_servicios.sql"]
print(f"  -> {len(planos_de_construccion)} planos listos para ser ejecutados.")


# --- PASO 3: LA EJECUCIÓN ORQUESTADA (El Maestro de Obras en Acción) ---
print("\n--- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---")

# La Anatomía: Iteramos sobre nuestra lista de planos.
for nombre_plano in planos_de_construccion:
    # La Lógica de Rutas del Maestro:
    # `ROOT_DIR / 'sql' / nombre_plano`: `pathlib` nos permite construir rutas
    # usando el operador `/` como si fueran carpetas. Es legible y robusto.
    # Esto crea la ruta ABSOLUTA y correcta al archivo .sql, sin importar
    # desde dónde ejecutes el notebook.
    ruta_plano_absoluta = ROOT_DIR / 'src' / 'sql' / nombre_plano
    
    # --- Verificaciones Opcionales para Cada Plano ---
    # Podemos añadir verificaciones específicas para cada paso.
    verify_query = None
    verify_label = None
    if nombre_plano == "04_insert_consultas.sql":
        verify_query = "SELECT COUNT(DISTINCT id_paciente) FROM consultas;"
        verify_label = "Conteo de Pacientes Únicos"
    
    if nombre_plano == "05_insert_consultas_servicios.sql":
        verify_query = "SELECT COUNT(*) FROM consultas_servicios;"
        verify_label = "Conteo de Pacientes Únicos"
        
    # Llamamos a nuestra poderosa función con la ruta absoluta.
    run_sql_file(
        engine,
        sql_path=str(ruta_plano_absoluta), # Convertimos a string para la función
        verify_query=verify_query,
        verify_label=verify_label
    )

print("\n\n--- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---")
# Out:
#   -> 2 planos listos para ser ejecutados.
#
# --- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/04_insert_consultas.sql ------
#    Success: 04_insert_consultas.sql executed
#    Verification -> Conteo de Pacientes Únicos: 637 registros.
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/05_insert_consultas_servicios.sql ------
#    Success: 05_insert_consultas_servicios.sql executed
#    Verification -> Conteo de Pacientes Únicos: 1229 registros.
#
#
# --- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---

# %%
planos_de_construccion = [
    "06_insert_consumo_productos.sql"]
print(f"  -> {len(planos_de_construccion)} planos listos para ser ejecutados.")


# --- PASO 3: LA EJECUCIÓN ORQUESTADA (El Maestro de Obras en Acción) ---
print("\n--- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---")

# La Anatomía: Iteramos sobre nuestra lista de planos.
for nombre_plano in planos_de_construccion:
    # La Lógica de Rutas del Maestro:
    # `ROOT_DIR / 'sql' / nombre_plano`: `pathlib` nos permite construir rutas
    # usando el operador `/` como si fueran carpetas. Es legible y robusto.
    # Esto crea la ruta ABSOLUTA y correcta al archivo .sql, sin importar
    # desde dónde ejecutes el notebook.
    ruta_plano_absoluta = ROOT_DIR / 'src' / 'sql' / nombre_plano
    
    # --- Verificaciones Opcionales para Cada Plano ---
    # Podemos añadir verificaciones específicas para cada paso.
    verify_query = None
    verify_label = None
    if nombre_plano == "06_insert_consumo_productos.sql":
        verify_query = "SELECT COUNT(*) FROM consumo_productos;"
        verify_label = "Conteo de Registros Realizados"
    
    
        
    # Llamamos a nuestra poderosa función con la ruta absoluta.
    run_sql_file(
        engine,
        sql_path=str(ruta_plano_absoluta), # Convertimos a string para la función
        verify_query=verify_query,
        verify_label=verify_label
    )

print("\n\n--- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---")
# Out:
#   -> 1 planos listos para ser ejecutados.
#
# --- ⚔️  Iniciando la Construcción del Templo desde los Planos Modulares... ---
#
#   ----- Running SQL: /mnt/c/DataScience/Projects_Python/Clinica_Prime/src/sql/06_insert_consumo_productos.sql ------
#    Success: 06_insert_consumo_productos.sql executed
#    Verification -> Conteo de Registros Realizados: 1232 registros.
#
#
# --- ✅ ¡CONSTRUCCIÓN DEL TEMPLO FINALIZADA! ---

# %%
# ======================================================================
# 🏛️ CONFIGURACIÓN DE LA HERRAMIENTA SQL
# ======================================================================
import prettytable

# La lista de estilos que vienen por defecto en la mayoría de versiones.
# MSWORD_FRIENDLY es uno de los más robustos y legibles.
print("Estilos de tabla disponibles:", prettytable.PLAIN_COLUMNS, prettytable.MSWORD_FRIENDLY, prettytable.DEFAULT)


# --- El Hechizo de Configuración ---
# La Anatomía: `%config SqlMagic.style = '...'`
# El Propósito del Artesano: Este es un "comando mágico" de IPython.
# Le estamos dando una orden directa a la extensión `ipython-sql`:
# "A partir de ahora, para TODAS tus salidas, no uses tu estilo por defecto.
# Usa el estilo que yo te ordeno: 'MSWORD_FRIENDLY'".
# %config SqlMagic.style = 'MSWORD_FRIENDLY'

print("\n✅ Estilo de la salida SQL configurado a 'MSWORD_FRIENDLY'.")
# %pip install ipython-sql==0.4.1 prettytable==3.6.0
# %reload_ext sql
# %pip install ipython-sql sqlalchemy psycopg2-binary
# %pip install psycopg2-binary
# %sql postgresql://postgres:postgres@localhost:5432/clinica_prime
# Out:
# Estilos de tabla disponibles: 12 11 10
#
# ✅ Estilo de la salida SQL configurado a 'MSWORD_FRIENDLY'.
# /tmp/ipykernel_23795/2322375237.py:8: DeprecationWarning: the 'PLAIN_COLUMNS' constant is deprecated, use the 'TableStyle' enum instead
#   print("Estilos de tabla disponibles:", prettytable.PLAIN_COLUMNS, prettytable.MSWORD_FRIENDLY, prettytable.DEFAULT)
# /tmp/ipykernel_23795/2322375237.py:8: DeprecationWarning: the 'MSWORD_FRIENDLY' constant is deprecated, use the 'TableStyle' enum instead
#   print("Estilos de tabla disponibles:", prettytable.PLAIN_COLUMNS, prettytable.MSWORD_FRIENDLY, prettytable.DEFAULT)
# /tmp/ipykernel_23795/2322375237.py:8: DeprecationWarning: the 'DEFAULT' constant is deprecated, use the 'TableStyle' enum instead
#   print("Estilos de tabla disponibles:", prettytable.PLAIN_COLUMNS, prettytable.MSWORD_FRIENDLY, prettytable.DEFAULT)
# ...
#   Using cached ipython_sql-0.4.1-py3-none-any.whl.metadata (17 kB)
# ...

# %%
# %%sql
# SELECT column_name
# FROM information_schema.columns
# WHERE table_name = 'raw_data'
# Out:
#  * postgresql://postgres:***@localhost:5432/clinica_prime
# 17 rows affected.
# [('fecha',),
#  ('nombre',),
#  ('teléfono',),
#  ('dni',),
#  ('sexo',),
#  ('distrito',),
#  ('total',),
#  ('paciente_problematico',),
#  ('texto_consulta',),
#  ('marcas_detectadas',),
#  ('servicios_realizados',),
#  ('nacimiento_year',),
#  ('nacimiento_month',),
#  ('nacimiento_day',),
#  ('consumos_detectados',),
#  ('deuda_monto',),
#  ('deuda_generada',)]
